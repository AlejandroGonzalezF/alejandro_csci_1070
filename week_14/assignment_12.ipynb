# %%
#pip install tensorflow

# %%
#pip install keras

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# %%
df = pd.read_csv("arrhythmia.data")
df.head()
# Out:
#    75  0  190  80   91  193  371  174  121  -16  ... 0.0.38   9.0 -0.9 0.0.39  \
# 0  56  1  165  64   81  174  401  149   39   25  ...    0.0   8.5  0.0    0.0
# 1  54  0  172  95  138  163  386  185  102   96  ...    0.0   9.5 -2.4    0.0
# 2  55  0  175  94  100  202  380  179  143   28  ...    0.0  12.2 -2.2    0.0
# 3  75  0  190  80   88  181  360  177  103  -16  ...    0.0  13.1 -3.6    0.0
# 4  13  0  169  51  100  167  321  174   91  107  ...   -0.6  12.2 -2.8    0.0
#
#   0.0.40  0.9.2  2.9.1  23.3  49.4   8
# 0    0.0    0.2    2.1  20.4  38.8   6
# 1    0.0    0.3    3.4  12.3  49.0  10
# 2    0.0    0.4    2.6  34.6  61.6   1
# 3    0.0   -0.1    3.9  25.4  62.8   7
# 4    0.0    0.9    2.2  13.5  31.1  14
#
# [5 rows x 280 columns]

# %%
null_data_sum = df.isnull().sum().sum()
object_columns = df.select_dtypes(include=['object']).columns

null_data_sum 
object_columns
# Out:
# Index(['13', '64', '-2', '?', '63'], dtype='object')

# %%
df.replace('?',np.nan,inplace=True)

# %%
df[object_columns] = df[object_columns].apply(pd.to_numeric)

# %%
df.drop('?',axis=1)
# Out:
#      75  0  190  80   91  193  371  174  121  -16  ...  0.0.38   9.0  -0.9  \
# 0    56  1  165  64   81  174  401  149   39   25  ...     0.0   8.5   0.0
# 1    54  0  172  95  138  163  386  185  102   96  ...     0.0   9.5  -2.4
# 2    55  0  175  94  100  202  380  179  143   28  ...     0.0  12.2  -2.2
# 3    75  0  190  80   88  181  360  177  103  -16  ...     0.0  13.1  -3.6
# 4    13  0  169  51  100  167  321  174   91  107  ...    -0.6  12.2  -2.8
# ..   .. ..  ...  ..  ...  ...  ...  ...  ...  ...  ...     ...   ...   ...
# 446  53  1  160  70   80  199  382  154  117  -37  ...     0.0   4.3  -5.0
# 447  37  0  190  85  100  137  361  201   73   86  ...     0.0  15.6  -1.6
# 448  36  0  166  68  108  176  365  194  116  -85  ...     0.0  16.3 -28.6
# 449  32  1  155  55   93  106  386  218   63   54  ...    -0.4  12.0  -0.7
# 450  78  1  160  70   79  127  364  138   78   28  ...     0.0  10.4  -1.8
#
#      0.0.39  0.0.40  0.9.2  2.9.1  23.3  49.4   8
# 0       0.0     0.0    0.2    2.1  20.4  38.8   6
# 1       0.0     0.0    0.3    3.4  12.3  49.0  10
# 2       0.0     0.0    0.4    2.6  34.6  61.6   1
# 3       0.0     0.0   -0.1    3.9  25.4  62.8   7
# 4       0.0     0.0    0.9    2.2  13.5  31.1  14
# ..      ...     ...    ...    ...   ...   ...  ..
# 446     0.0     0.0    0.7    0.6  -4.4  -0.5   1
# 447     0.0     0.0    0.4    2.4  38.0  62.4  10
# 448     0.0     0.0    1.5    1.0 -44.2 -33.2   2
# 449     0.0     0.0    0.5    2.4  25.0  46.6   1
# 450     0.0     0.0    0.5    1.6  21.3  32.8   1
#
# [451 rows x 279 columns]

# %%
df.fillna(df.median(numeric_only=True), inplace=True)

na_after_cleaning = df.isna().sum().sum()
na_after_cleaning
# Out:
# np.int64(0)

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, :-1].values

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train_tensor = torch.FloatTensor(X_train)
X_test_tensor = torch.FloatTensor(X_test)

y_test_tensor = torch.LongTensor(y_test)
y_train_tensor = torch.LongTensor(y_train)

# %%
train_df = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_df, batch_size=32, shuffle=True)

# %%
class ANN_Model(nn.Module):
    def __init__(self, input_features=8,hidden1=20,hidden2=20,out_features=2):
        super(ANN_Model, self).__init__() 
        self.layer_1_connection = nn.Linear(input_features, hidden1)
        self.layer_2_connection = nn.Linear(hidden1, hidden2)
        self.out = nn.Linear(hidden2, out_features)

    def forward(self, x):
        x = F.relu(self.layer_1_connection(x))
        x = F.relu(self.layer_2_connection(x))
        x = self.out(x)
        return x

# %%
torch.manual_seed(42)
input_size = X_train.shape[1]
hidden_size = 64
output_size = len(np.unique(y_train))

ann = ANN_Model(input_size, hidden_size, output_size)
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(ann.parameters(), lr = 0.01)

final_loss = []
n_epochs = 500
for epoch in range(n_epochs):
    y_pred = ann.forward(X_train)
    loss = loss_function(y_pred, y_train)
    final_loss.append(loss)

    if epoch % 10 == 1:
        print(f'Epoch number: {epoch} with loss {loss}')

    optimizer.zero_grad() 
    loss.backward() 
    optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[305], line 13
#      11 n_epochs = 500
#      12 for epoch in range(n_epochs):
# ---> 13     y_pred = ann.forward(X_train)
#      14     loss = loss_function(y_pred, y_train)
#      15     final_loss.append(loss)
#
# Cell In[304], line 9, in ANN_Model.forward(self, x)
#       8 def forward(self, x):
# ----> 9     x = F.linear(self.layer_1_connection(x))
#      10     x = F.linear(self.layer_2_connection(x))
#      11     x = self.out(x)
#
# File c:\Users\jagz0\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jagz0\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\jagz0\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# TypeError: linear(): argument 'input' (position 1) must be Tensor, not numpy.ndarray

# %%
y_pred = []

with torch.no_grad(): 
    for i, data in enumerate(X_test):
        prediction = ann(data)
        y_pred.append(prediction.argmax())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[271], line 5
#       3 with torch.no_grad():
#       4     for i, data in enumerate(X_test):
# ----> 5         prediction = ann(data)
#       6         y_pred.append(prediction.argmax())
#
# File c:\Users\jagz0\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jagz0\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[268], line 9, in ANN_Model.forward(self, x)
#       8 def forward(self, x):
# ----> 9     x = F.relu(self.layer_1_connection(x))
#      10     x = F.relu(self.layer_2_connection(x))
#      11     #x = self.out(x)
#
# File c:\Users\jagz0\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jagz0\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\jagz0\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# TypeError: linear(): argument 'input' (position 1) must be Tensor, not numpy.ndarray
