# %% [markdown]
# ![image.png](attachment:182285e1-3984-43d3-856f-6d749e983087.png)

# %%
#Q2. alex_csci_1070 is my personal repo, it has the week_01 folder, which will contain the work done on this week. 
#csci_1070 is the cloned repo from the teacher, it has the week 1 folder which should have the cloned work from github.
#Notes is for class notes and daily warm-ups, but I haven't moved them over yet. (sorry)

# %%
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]
for month in months:
    print(month)
    if month == "March":
        print ("My Birthday")
# Out:
# January
# February
# March
# My Birthday
# April
# May
# June
# July
# August
# September
# October
# November
# December
